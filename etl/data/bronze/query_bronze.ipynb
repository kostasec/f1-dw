# %%
import pandas as pd

# %%
df=pd.read_parquet('f1_data.parquet')

# %%
df=pd.read_csv('f1_data.csv')
df
# Out:
# C:\Users\Vojo\AppData\Local\Temp\ipykernel_2532\62102091.py:1: DtypeWarning: Columns (0: position, 1: positionText, 2: milliseconds, 3: fastestLap, 4: fastestLapSpeed, 5: alt, 6: number_drivers, 7: duration) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('f1_data.csv')
#         Unnamed: 0  resultId  raceId  driverId  constructorId  number  grid  \
# 0                0     21232     860        18              1       3     2
# 1                1     21232     860        18              1       3     2
# 2                2     21232     860        18              1       3     2
# 3                3     21232     860        18              1       3     2
# 4                4     21232     860        18              1       3     2
# ...            ...       ...     ...       ...            ...     ...   ...
# 518412      518412     23041     953       837            209      88    19
# ...
